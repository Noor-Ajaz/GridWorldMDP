# %%
# Upgrade pip (optional, but recommended)
# !pip install --upgrade pip

# Install Streamlit, Numpy, Matplotlib
# !pip install streamlit numpy matplotlib
# Out:
# ...
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/1.8 MB ? eta -:--:--
#    ----------- ---------------------------- 0.5/1.8 MB 1.2 MB/s eta 0:00:02
#    ----------------- ---------------------- 0.8/1.8 MB 1.0 MB/s eta 0:00:01
#    ----------------------- ---------------- 1.0/1.8 MB 995.8 kB/s eta 0:00:01
#    ----------------------- ---------------- 1.0/1.8 MB 995.8 kB/s eta 0:00:01
#    ----------------------------- ---------- 1.3/1.8 MB 815.1 kB/s eta 0:00:01
#    ----------------------------------- ---- 1.6/1.8 MB 888.6 kB/s eta 0:00:01
# ...

# %%
# Use Anaconda's Python to install libraries
# !C:\Users\66957\anaconda3\python.exe -m pip install --upgrade pip
# !C:\Users\66957\anaconda3\python.exe -m pip install streamlit numpy matplotlib
# Out:
# ...
#   Using cached pip-25.3-py3-none-any.whl.metadata (4.7 kB)
# Using cached pip-25.3-py3-none-any.whl (1.8 MB)
# ...
#   Attempting uninstall: pip
#     Found existing installation: pip 25.1
#     Uninstalling pip-25.1:
#       Successfully uninstalled pip-25.1
# ...

# %%
# !C:\Users\66957\anaconda3\python.exe -m streamlit run app.py
